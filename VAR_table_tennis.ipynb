# %% [markdown]
# <a href="https://colab.research.google.com/github/radoslawierzbicki/VAR_table_tennis/blob/main/VAR_table_tennis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("it will be a VAR for Table Tennis!")
# Out:
# its VAR for Table Tennis!

# %% [markdown]
# Projekt VARu w tenisie stołowym

# %%
print("🏓")
# Out:
# 🏓
